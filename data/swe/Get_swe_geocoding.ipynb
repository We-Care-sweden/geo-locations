# %%
import pandas as pd
import urllib
import json
import time
from tqdm import tqdm


def num2postal_code(num):
    output = str(num)
    while len(output) < 5:
        output = '0'+output
    return output 
    
df = pd.DataFrame ({'country_code':[], 
                    'postal_code':[],
                    'latitude':[],
                    'longitude':[],
                    'region_id':[]
                   }
                  )


# Google API Key
f = open('apikey.txt', 'r')
key = f.readline()
f.close()

key='AIzaSyBLajtEW1U5IKazMZOofxEnZqRAXyVXbaI'

# %%
zipcodeList = range(4864,10000)

for code in tqdm(zipcodeList):
    #if np.mod(code,100)==1:
    #    print('progress: code)
    zipcode = num2postal_code(code)
    url='https://maps.googleapis.com/maps/api/geocode/json?address=' + zipcode + 'Sweden&key=' + key
    response = urllib.request.urlopen(url)
    data = json.loads(response.read())
    if data['status']=='OK' and data['results'][0]['address_components'][-1]['long_name'] == 'Sweden':
        s='::'
        if len(data['results'][0]['address_components'])==5:
            df = df.append(
                        {'country_code':data['results'][0]['address_components'][-1]['long_name'], 
                         'postal_code':zipcode,
                         'latitude':data['results'][0]['geometry']['location']['lat'],
                         'longitude':data['results'][0]['geometry']['location']['lng'],
                         'region_id':s.join((data['results'][0]['address_components'][1]['long_name'], 
                                         data['results'][0]['address_components'][2]['long_name']))
                        }, ignore_index=True)
        elif len(data['results'][0]['address_components'])==2:
            df = df.append(
                        {'country_code':data['results'][0]['address_components'][-1]['long_name'], 
                         'postal_code':zipcode,
                         'latitude':data['results'][0]['geometry']['location']['lat'],
                         'longitude':data['results'][0]['geometry']['location']['lng'],
                         'region_id':s.join(('Sweden','Sweden'))
                        }, ignore_index=True)

df_all['country_code'] = 'swe'

import pickle
with open('swe_geocoding', 'wb') as f:
    pickle.dump(df, f)

df.to_csv('swe_geocoding.csv')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 5136/5136 [36:38<00:00,  2.62it/s]

# %%
with open('df2', 'rb') as f:
    df2 = pickle.load(f)
with open('df3', 'rb') as f:
    df3 = pickle.load(f)
with open('df4', 'rb') as f:
    df4 = pickle.load(f)
with open('df5', 'rb') as f:
    df5 = pickle.load(f)
with open('df6', 'rb') as f:
    df6 = pickle.load(f)
with open('df7', 'rb') as f:
    df7 = pickle.load(f)
with open('df8', 'rb') as f:
    df8 = pickle.load(f)
with open('df9', 'rb') as f:
    df9 = pickle.load(f)
with open('df10', 'rb') as f:
    df10 = pickle.load(f)
    
    
df_all = pd.concat([df, df2, df3, df4, df5, df6, df7, df8, df9, df10], ignore_index= "true")

# %%
df_all.to_csv('swe_geocoding.csv')

# %%
# Out:
#      country_code postal_code   latitude  longitude  \
# 0             swe       10465  59.320134  18.069641
# 1             swe       11121  59.332429  18.060318
# 2             swe       11124  59.336452  18.053005
# 8             Norrmalm::Stockholm
# 9             Norrmalm::Stockholm
# 10            Norrmalm::Stockholm
# 11            Norrmalm::Stockholm
# 12            Norrmalm::Stockholm
# 13            Norrmalm::Stockholm
# 14            Norrmalm::Stockholm
# 15            Norrmalm::Stockholm
# 16            Norrmalm::Stockholm
# 17            Norrmalm::Stockholm
# 18            Norrmalm::Stockholm
# 19            Norrmalm::Stockholm
# 20            Norrmalm::Stockholm
# 21         Kungsholmen::Stockholm
# 22         Kungsholmen::Stockholm
# 23         Kungsholmen::Stockholm
# 24         Kungsholmen::Stockholm
# 25         Kungsholmen::Stockholm
# 26         Kungsholmen::Stockholm
# 27         Kungsholmen::Stockholm
# 28         Kungsholmen::Stockholm
# 29         Kungsholmen::Stockholm
# ...                           ...
# 3119      Östermalm, Luleå::Luleå
# 3120      Östermalm, Luleå::Luleå
# 3121      Östermalm, Luleå::Luleå
# 3122      Östermalm, Luleå::Luleå
# 3123      Östermalm, Luleå::Luleå
# 3124             Bergnäset::Luleå
# 3125   Notviken-Mjölkudden::Luleå
# 3126      Östermalm, Luleå::Luleå
# 3127      Östermalm, Luleå::Luleå
# 3128      Östermalm, Luleå::Luleå
# 3129      Östermalm, Luleå::Luleå
# 3130      Östermalm, Luleå::Luleå
# 3131      Östermalm, Luleå::Luleå
# 3132               Luleå Ö::Luleå
# 3133               Luleå Ö::Luleå
# 3134           Björkskatan::Luleå
# 3135               Luleå Ö::Luleå
# 3136                Porsön::Luleå
# 3137                Porsön::Luleå
# 3138         Kiruna Ö::Lannavaara
# 3139            Pajala S::Tärendö
# 3140             Pajala N::Kangos
# 3141              Centrum::Kiruna
# 3142              Centrum::Kiruna
# 3143             Norrmalm::Kiruna
# 3144  Glaciären-Solvinden::Kiruna
# 3145         Kiruna N::Kurravaara
# 3146        Kiruna N::Jukkasjärvi
# 3147  Gällivare NV::Koskullskulle
# 3148  Gällivare NV::Koskullskulle
#
# [3149 rows x 5 columns]

# %%
zipcode = '17152'
url='https://maps.googleapis.com/maps/api/geocode/json?address=' + zipcode + 'Sweden&key=' + key
response = urllib.request.urlopen(url)
data = json.loads(response.read())
if data['status']=='OK' and data['results'][0]['address_components'][4]['long_name'] == 'Sweden':
        s='::'
        df = df.append(
                        {'country_code':data['results'][0]['address_components'][4]['long_name'], 
                         'postal_code':zipcode,
                         'latitude':data['results'][0]['geometry']['location']['lat'],
                         'longitude':data['results'][0]['geometry']['location']['lng'],
                         'region_id':s.join((data['results'][0]['address_components'][1]['long_name'], 
                                         data['results'][0]['address_components'][2]['long_name']))
                        }, ignore_index=True)



print(len(data['results'][0]['address_components']))

data['results'][0]['address_components']
