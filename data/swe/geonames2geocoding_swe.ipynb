# %%
import os
import pandas as pd
# import seaborn as sns
from pathlib import Path
import numpy as np

def set_correct_working_dir(working_dir: str):
    current_working_dir = Path(os.getcwd())
    if working_dir == current_working_dir.name:
        print('WD correct')
        return
    for directory in current_working_dir.parents:
        if working_dir == directory.name:
            os.chdir(str(directory.absolute()))
            print('New WD:', str(directory.absolute()))
            return
    raise FileNotFoundError

set_correct_working_dir('geo-locations')
# Out:
# New WD: /home/avmo/src/projects/covidmap-sweden/geo-locations

# %% [markdown]
# ### Reading in data

# %%
country_code = 'swe'
source = 'geonames'
country_path = Path(os.getcwd()) / 'data' / country_code
source = country_path / '_'.join(['source', source]) / 'SE.txt'
# column description to be found at: https://download.geonames.org/export/zip/
geonames_df = pd.read_csv(
    source,
    sep='\t',
    names=['country_code ', 'postal_code', 'place_name', 'admin_name_1', 'admin_code_1', 'admin_name_2', 'admin_code_2', 'admin_name_3', 'admin_code_3', 'latitude', 'longitude', 'accuracy'],
    converters={'postal_code': str},
)
geonames_df.fillna('', inplace=True)
display(geonames_df.head())
# Out:
#   country_code  postal_code  place_name admin_name_1 admin_code_1  \
# 0            SE      186 00  Vallentuna    Stockholm           AB
# 1            SE      186 01  Vallentuna    Stockholm           AB
# 2            SE      186 03     Brottby    Stockholm           AB
# 3            SE      186 21  Vallentuna    Stockholm           AB
# 4            SE      186 22  Vallentuna    Stockholm           AB
#
#   admin_name_2 admin_code_2 admin_name_3 admin_code_3  latitude  longitude  \
# 0   Vallentuna          115                             59.5344    18.0776
# 1   Vallentuna          115                             59.5344    18.0776
# 2   Vallentuna          115                             59.5632    18.2403
# 3   Vallentuna          115                             59.5344    18.0776
# 4   Vallentuna          115                             59.5344    18.0776
#
#   accuracy
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
# Convert postal code to integers "186 00" -> 18600
geonames_df.postal_code = geonames_df.postal_code.apply(lambda pc: int(''.join(pc.split())))

# %%
try:
    geonames_df.drop(columns=['admin_code_1', 'admin_code_2', 'admin_code_3', 'accuracy'], inplace=True)
except KeyError:
    pass
geonames_df.fillna(np.NaN)
for str_col in ['admin_name_1', 'admin_name_2', 'admin_name_3', 'place_name']:
    geonames_df.loc[(geonames_df[str_col].isnull(), 'admin_name_3')] = ''  # empty string for string columns

geonames_df.loc[(geonames_df['admin_name_2'] == geonames_df['admin_name_3'], 'admin_name_3')] = ''

geonames_df = geonames_df.groupby('postal_code').agg({'admin_name_1': lambda col: ';'.join(col),
                                                      'admin_name_2': lambda col: ';'.join(col),
                                                      'admin_name_3': lambda col: ';'.join(col), 
                                                      'place_name': lambda col: '||'.join(col),
                                                      'latitude': 'mean',
                                                      'longitude': 'mean'}).reset_index()

geonames_df['admin_name_1'] = geonames_df['admin_name_1'].apply(lambda x: ';'.join(list(set([y for y in x.split(';') if y]))) if ';' in x else x)
geonames_df['admin_name_2'] = geonames_df['admin_name_2'].apply(lambda x: ';'.join(list(set([y for y in x.split(';') if y]))) if ';' in x else x)
geonames_df['admin_name_3'] = geonames_df['admin_name_3'].apply(lambda x: ';'.join(list(set([y for y in x.split(';') if y]))) if ';' in x else x)
geonames_df.loc[(geonames_df['admin_name_3'] == '', 'region_id')] = geonames_df['admin_name_1'] + '::' + geonames_df['admin_name_2'] + '::' + geonames_df['place_name']
geonames_df.loc[(geonames_df['admin_name_3'] != '', 'region_id')] = geonames_df['admin_name_1'] + '::' + geonames_df['admin_name_2'] + '::' + geonames_df['admin_name_3'] + '::' + geonames_df['place_name']
geonames_df.reset_index(inplace=True, drop=True)
geonames_df.sort_values('postal_code', inplace=True)
geonames_df.insert(loc=0, column='country_code', value=country_code)
geonames_df = geonames_df.round({'latitude': 4, 'longitude': 4})

# %%
geonames_df.head(50)
# Out:
#    country_code  postal_code admin_name_1 admin_name_2 admin_name_3  \
# 0           swe        10005    Stockholm    Stockholm
# 1           swe        10012    Stockholm    Stockholm
# 2           swe        10026    Stockholm    Stockholm
# 3           swe        10028    Stockholm    Stockholm
# 4           swe        10029    Stockholm    Stockholm
# 5           swe        10031    Stockholm    Stockholm
# 6           swe        10040    Stockholm    Stockholm
# 7           swe        10041    Stockholm    Stockholm
# 8           swe        10044    Stockholm    Stockholm
# 9           swe        10052    Stockholm    Stockholm
# 10          swe        10054    Stockholm    Stockholm
# 11          swe        10055    Stockholm    Stockholm
# 12          swe        10061    Stockholm    Stockholm
# 13          swe        10064    Stockholm    Stockholm
# 14          swe        10073    Stockholm    Stockholm
# 15          swe        10074    Stockholm    Stockholm
# 16          swe        10101    Stockholm
# 17          swe        10110    Stockholm    Stockholm
# 18          swe        10120    Stockholm    Stockholm
# 19          swe        10121    Stockholm    Stockholm
# 20          swe        10122    Stockholm    Stockholm
# 21          swe        10123    Stockholm    Stockholm
# 22          swe        10124    Stockholm    Stockholm
# 23          swe        10125    Stockholm    Stockholm
# 24          swe        10126    Stockholm    Stockholm
# 25          swe        10127    Stockholm    Stockholm
# 26          swe        10128    Stockholm    Stockholm
# 27          swe        10129    Stockholm    Stockholm
# 28          swe        10130    Stockholm    Stockholm
# 29          swe        10131    Stockholm    Stockholm
# 30          swe        10132    Stockholm    Stockholm
# 31          swe        10133    Stockholm    Stockholm
# 32          swe        10134    Stockholm    Stockholm
# 33          swe        10135    Stockholm    Stockholm
# 34          swe        10136    Stockholm    Stockholm
# 35          swe        10137    Stockholm    Stockholm
# 36          swe        10138    Stockholm    Stockholm
# 37          swe        10139    Stockholm    Stockholm
# 38          swe        10152    Stockholm    Stockholm
# 39          swe        10153    Stockholm
# 40          swe        10154    Stockholm
# 41          swe        10155    Stockholm    Stockholm
# 42          swe        10156    Stockholm    Stockholm
# 43          swe        10158    Stockholm    Stockholm
# 44          swe        10159    Stockholm
# 45          swe        10204    Stockholm    Stockholm
# 46          swe        10214    Stockholm    Stockholm
# 47          swe        10215    Stockholm
# 48          swe        10216    Stockholm
# 49          swe        10218    Stockholm
#
#    place_name  latitude  longitude                        region_id
# 0   Stockholm   59.3326    18.0649  Stockholm::Stockholm::Stockholm
#
# 16402         Pajala   67.2128    23.3661
#
#                                   region_id
# 16353      Norrbotten::Gällivare::Gällivare
# 16354      Norrbotten::Gällivare::Gällivare
# 16355      Norrbotten::Gällivare::Gällivare
# 16356     Norrbotten::Gällivare::Nattavaara
# 16357   Norrbotten::Gällivare::Nattavaaraby
# 16358               Norrbotten::::Gällivare
# 16359      Norrbotten::Gällivare::Gällivare
# 16360      Norrbotten::Gällivare::Gällivare
# 16361      Norrbotten::Gällivare::Gällivare
# 16362      Norrbotten::Gällivare::Gällivare
# 16363      Norrbotten::Gällivare::Gällivare
# 16364      Norrbotten::Gällivare::Gällivare
# 16365      Norrbotten::Gällivare::Gällivare
# 16366      Norrbotten::Gällivare::Gällivare
# 16367      Norrbotten::Gällivare::Gällivare
# 16368      Norrbotten::Gällivare::Gällivare
# 16369          Norrbotten::Jokkmokk::Porjus
# 16370      Norrbotten::Gällivare::Gällivare
# 16371      Norrbotten::Gällivare::Gällivare
# 16372      Norrbotten::Gällivare::Gällivare
# 16373      Norrbotten::Gällivare::Gällivare
# 16374      Norrbotten::Gällivare::Gällivare
# 16375  Norrbotten::Gällivare::Koskullskulle
# 16376              Norrbotten::::Malmberget
# 16377     Norrbotten::Gällivare::Malmberget
# 16378     Norrbotten::Gällivare::Malmberget
# 16379     Norrbotten::Gällivare::Malmberget
# 16380  Norrbotten::Gällivare::Koskullskulle
# 16381     Norrbotten::Gällivare::Malmberget
# 16382     Norrbotten::Gällivare::Malmberget
# 16383     Norrbotten::Gällivare::Malmberget
# 16384     Norrbotten::Gällivare::Malmberget
# 16385     Norrbotten::Gällivare::Malmberget
# 16386     Norrbotten::Gällivare::Malmberget
# 16387  Norrbotten::Gällivare::Koskullskulle
# 16388     Norrbotten::Gällivare::Malmberget
# 16389            Norrbotten::Pajala::Pajala
# 16390                  Norrbotten::::Pajala
# 16391            Norrbotten::Pajala::Pajala
# 16392            Norrbotten::Pajala::Pajala
# 16393            Norrbotten::Pajala::Pajala
# 16394            Norrbotten::Pajala::Pajala
# 16395            Norrbotten::Pajala::Pajala
# 16396            Norrbotten::Pajala::Pajala
# 16397            Norrbotten::Pajala::Pajala
# 16398            Norrbotten::Pajala::Pajala
# 16399            Norrbotten::Pajala::Pajala
# 16400           Norrbotten::Pajala::Lovikka
# 16401     Norrbotten::Pajala::Muodoslompolo
# 16402            Norrbotten::Pajala::Pajala

# %%
geonames_df.dtypes
# Out:
# country_code     object
# postal_code       int64
# admin_name_1     object
# admin_name_2     object
# admin_name_3     object
# place_name       object
# latitude        float64
# longitude       float64
# region_id        object
# dtype: object

# %%
try:
    geonames_df.drop(columns=['admin_name_1', 'admin_name_2', 'admin_name_3', 'place_name'], inplace=True)
except KeyError:
    pass
file_path = country_path / '_'.join([country_code, 'geocoding.csv'])
geonames_df.to_csv(file_path, index=False)
